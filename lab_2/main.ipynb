# %%
from huggingface_hub import InferenceClient
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
def identify_tank(prompt: str, image_url: str, model: str, api_key: str) -> str:
    client = InferenceClient(api_key=api_key)

    completion = client.chat.completions.create(
        model=model,
        messages=[
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": prompt},
                    {"type": "image_url", "image_url": {"url": image_url}},
                ],
            }
        ],
    )

    return completion.choices[0].message.content

# %%
MODEL = "Qwen/Qwen3-VL-30B-A3B-Instruct:novita"

PROMPT = "Write one word: Soviet if the picture shows a Soviet tank, German if the picture shows a German tank."

IMAGE_URL = (
    "https://topwar.ru/uploads/posts/2019-04/1554666808_1358205471-0991154-www_nevsepic_com_ua.jpg"
)

HF_TOKEN = os.environ["HF_TOKEN"]

# %%
identify_tank(prompt=PROMPT, image_url=IMAGE_URL, model=MODEL, api_key=HF_TOKEN)
# Out:
# 'Soviet'
